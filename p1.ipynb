# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\coding\pandas\datasets\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# ### Q1. Display those records where country is Andorra.

# %%
df[df['Country'].isin(['Andorra'])]
# Out:
#    Rank CCA3  Country           Capital Continent  2022 Population  \
# 4   203  AND  Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 4          53569.0          35611.0          19860.0       468.0
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 4           170.5641         1.01                          0.0

# %% [markdown]
# ### Q2. Display those records where countries are Andorra, Algeria and India.

# %%
lst = ['Andorra', 'India', 'Algeria']
df[df['Country'].isin(lst)]
# Out:
#     Rank CCA3  Country           Capital Continent  2022 Population  \
# 2     34  DZA  Algeria           Algiers    Africa     4.490322e+07
# 4    203  AND  Andorra  Andorra la Vella    Europe     7.982400e+04
# 92     2  IND    India         New Delhi      Asia     1.417173e+09
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 2      4.345167e+07     3.954315e+07     3.585634e+07     3.077462e+07
# 4      7.770000e+04     7.174600e+04     7.151900e+04     6.609700e+04
# 92     1.396387e+09     1.322867e+09     1.240614e+09     1.059634e+09
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 2        25518074.0       18739378.0       13795915.0   2381741.0
# 4           53569.0          35611.0          19860.0       468.0
# 92              NaN              NaN      557501301.0   3287590.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 2             18.8531       1.0164                         0.56
# ...

# %% [markdown]
# ### Q3. Only the capital column of all the records.

# %%
df.filter(items=["Capital"])
# Out:
#               Capital
# 0               Kabul
# 1              Tirana
# 2             Algiers
# 3           Pago Pago
# 4    Andorra la Vella
# ..                ...
# 229          Mata-Utu
# 230          El Aaiún
# 231             Sanaa
# 232            Lusaka
# 233            Harare
#
# [234 rows x 1 columns]

# %% [markdown]
# ### Q4. Display only the capital column of those record where rank is less than equal to 15.

# %%
temp_df = df[df['Rank'] < 15]
temp_df
t1=temp_df.filter(items=['Capital'])
t1
# Out:
#               Capital
# 16              Dhaka
# 27           Brasilia
# 41            Beijing
# 57              Cairo
# 63        Addis Ababa
# 92          New Delhi
# 93            Jakarta
# 102             Tokyo
# 131       Mexico City
# 149             Abuja
# 156         Islamabad
# 163            Manila
# 171            Moscow
# 221  Washington, D.C.

# %% [markdown]
# ### Q5 Display the first 6 records of the above question

# %%
t1.head(6)
# Out:
#         Capital
# 16        Dhaka
# 27     Brasilia
# 41      Beijing
# 57        Cairo
# 63  Addis Ababa
# 92    New Delhi

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# ### Q6. Sort the records in ascending order based on continent.

# %%
res = df.sort_values(by=['Continent'])
res
# Out:
#      Rank CCA3                Country     Capital      Continent  \
# 233    74  ZWE               Zimbabwe      Harare         Africa
# 34     53  CMR               Cameroon     Yaounde         Africa
# 181   187  STP  Sao Tome and Principe    São Tomé         Africa
# 36    171  CPV             Cape Verde       Praia         Africa
# 172    76  RWA                 Rwanda      Kigali         Africa
# ..    ...  ...                    ...         ...            ...
# 64    231  FLK       Falkland Islands     Stanley  South America
# 27      7  BRA                 Brazil    Brasilia  South America
# 199   170  SUR               Suriname  Paramaribo  South America
# 223   133  URY                Uruguay  Montevideo  South America
# 24     80  BOL                Bolivia       Sucre  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 233       16320537.0       15669666.0       14154937.0       12839771.0
# ...

# %% [markdown]
# ### Q7. Sort the records in descending order based on 'Country'.

# %%
df.sort_values(by=['Country'], ascending=False)
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 233    74  ZWE           Zimbabwe            Harare    Africa
# 232    63  ZMB             Zambia            Lusaka    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# ..    ...  ...                ...               ...       ...
# 4     203  AND            Andorra  Andorra la Vella    Europe
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 2      34  DZA            Algeria           Algiers    Africa
# 1     138  ALB            Albania            Tirana    Europe
# 0      36  AFG        Afghanistan             Kabul      Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 233       16320537.0       15669666.0       14154937.0       12839771.0
# 232       20017675.0       18927715.0              NaN       13792086.0
# ...

# %% [markdown]
# ### Q8. Display the result of all the records where Rank is less than 10. Show the result in descending order first based on Continent, then Country.

# %%
df[df['Rank']< 10].sort_values(by=['Continent', 'Country'], ascending=[False, True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 221     3.382899e+08     3.359420e+08     3.246078e+08     3.111828e+08
# 171     1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# ...

# %% [markdown]
# ### Q9. Display the result of all the records where Rank is less than 10. Show the result in descending order first based on Continent, then Country. Display only 2022 population result.

# %%
t1 = df[df['Rank'] < 10].sort_values(by=['Continent', 'Country'], ascending=[False, True])
res = t1.filter(items=['2022 Population'], axis=1)
res
# Out:
#      2022 Population
# 27      2.153135e+08
# 221     3.382899e+08
# 171     1.447133e+08
# 16      1.711864e+08
# 41      1.425887e+09
# 92      1.417173e+09
# 93      2.755013e+08
# 156     2.358249e+08
# 149     2.185412e+08
